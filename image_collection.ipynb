# %%
# !pip install opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Import Dependencies

# %%
import cv2
import uuid
import os
import time

# %% [markdown]
# # 2. Define Images to Collect

# %%
labels = ['thumbsup', 'thumbsdown', 'thankyou', 'livelong']
number_images = 5

# %% [markdown]
# # 3. Setup Folders

# %%
IMAGES_PATH = '/content/drive/MyDrive/Colab Notebooks/summer/object_detection /tutorial /data/images/collectedimages'

for label in labels:
  path = os.path.join(IMAGES_PATH, label)
  if not os.path.exists(path):
    os.makedirs(path)

# %% [markdown]
# # 4. Capture Images

# %%
for label in labels:
  cap = cv2.VideoCapture(0)
  print(f'Collecting images for {label}')
  time.sleep(5)

  for imgnum in range(number_images):
    print(f'Collecting image {imgnum}')
    ret, frame = cap.read()
    imgname = os.path.join(IMAGES_PATH, label, f'{label}.{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    cv2.imshow('frame', frame)
    time.sleep(2)

    if cv2.waitKey(1) and 0xFF == ord('q'):
      break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-edd49f4a6388> in <cell line: 1>()
#       8     ret, frame = cap.read()
#       9     imgname = os.path.join(IMAGES_PATH, label, f'{label}.{str(uuid.uuid1())}.jpg')
# ---> 10     cv2.imwrite(imgname, frame)
#      11     cv2.imshow('frame', frame)
#      12     time.sleep(2)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:787: error: (-215:Assertion failed) !_img.empty() in function 'imwrite'

# %% [markdown]
# # 5. Image labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.1/338.1 kB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 9.0 MB/s eta 0:00:00
# ...

# %%
LABELIMG_PATH = '/content/drive/MyDrive/Colab Notebooks/summer/object_detection /tutorial /data/images/labelimg'

# %% [markdown]
# # 6. Move them into a Training and Testing Partition
